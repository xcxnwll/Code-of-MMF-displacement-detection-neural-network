bmp
#   inflating: /content/gdrive/MyDrive/imaging/classification/input/400nm/1147.bmp
#   inflating: /content/gdrive/MyDrive/imaging/classification/input/400nm/1148.bmp
#   inflating: /content/gdrive/MyDrive/imaging/classification/input/400nm/1149.bmp
#   inflating: /content/gdrive/MyDrive/imaging/classification/input/400nm/115.bmp
#   inflating: /content/gdrive/MyDrive/imaging/classification/input/400nm/1150.bmp
#   inflating: /content/gdrive/MyDrive/imaging/classification/input/400nm/1151.bmp
#   inflating: /content/gdrive/MyDrive/imaging/classification/input/400nm/1152.bmp
#   inflating: /content/gdrive/MyDrive/imaging/classification/input/400nm/1153.bmp
#   inflating: /content/gdrive/MyDrive/imaging/classification/input/400nm/1154.bmp
#   inflating: /content/gdrive/MyDrive/imaging/classification/input/400nm/1155.bmp
#   inflating: /content/gdrive/MyDrive/imaging/classification/input/400nm/1156.bmp
#   inflating: /content/gdrive/MyDrive/imaging/classification/input/400nm/1157.bmp
#   inflating: /content/gdrive/MyDrive/imaging/classification/input/400nm/1158.bmp
#   inflating: /content/gdrive/MyDrive/imaging/classification/input/400nm/1159.bmp
#   inflating: /content/gdrive/MyDrive/imaging/classification/input/400nm/116.bmp
#   inflating: /content/gdrive/MyDrive/imaging/classification/input/400nm/1160.bmp
#   inflating: /content/gdrive/MyDrive/imaging/classification/input/400nm/1161.bmp
#   inflating: /content/gdrive/MyDrive/imaging/classification/input/400nm/1162.bmp
#   inflating: /content/gdrive/MyDrive/imaging/classification/input/400nm/1163.bmp
#   inflating: /content/gdrive/MyDrive/imaging/classification/input/400nm/1164.bmp
#   inflating: /content/gdrive/MyDrive/imaging/classification/input/400nm/1165.bmp
#   inflating: /content/gdrive/MyDrive/imaging/classification/input/400nm/1166.bmp
#   inflating: /content/gdrive/MyDrive/imaging/classification/input/400nm/1167.bmp
#   inflating: /content/gdrive/MyDrive/imaging/classification/input/400nm/1168.bmp
#   inflating: /content/gdrive/MyDrive/imaging/classification/input/400nm/1169.bmp
#   inflating: /content/gdrive/MyDrive/imaging/classification/input/400nm/117.bmp
#   inflating: /content/gdrive/MyDrive/imaging/classification/input/400nm/1170.bmp
#   inflating: /content/gdrive/MyDrive/imaging/classification/input/400nm/1171.bmp
#   inflating: /content/gdrive/MyDrive/imaging/classification/input/400nm/1172.bmp
#   inflating: /content/gdrive/MyDrive/imaging/classification/input/400nm/1173.bmp
#   inflating: /content/gdrive/MyDrive/imaging/classification/input/400nm/1174.bmp
#   inflating: /content/gdrive/MyDrive/imaging/classification/input/400nm/1175.bmp
#   inflating: /content/gdrive/MyDrive/imaging/classification/input/400nm/1176.bmp
#   inflating: /content/gdrive/MyDrive/imaging/classification/input/400nm/1177.bmp
#   inflating: /content/gdrive/MyDrive/imaging/classification/input/400nm/1178.bmp
#   inflating: /content/gdrive/MyDrive/imaging/classification/input/400nm/1179.bmp
#   inflating: /content/gdrive/MyDrive/imaging/classification/input/400nm/118.bmp
#   inflating: /content/gdrive/MyDrive/imaging/classification/input/400nm/1180.bmp
#   inflating: /content/gdrive/MyDrive/imaging/classification/input/400nm/1181.bmp
#   inflating: /content/gdrive/MyDrive/imaging/classification/input/400nm/1182.bmp
#   inflating: /content/gdrive/MyDrive/imaging/classification/input/400nm/1183.bmp
#   inflating: /content/gdrive/MyDrive/imaging/classification/input/400nm/1184.bmp
#   inflating: /content/gdrive/MyDrive/imaging/classification/input/400nm/1185.bmp
#   inflating: /content/gdrive/MyDrive/imaging/classification/input/400nm/1186.bmp
#   inflating: /content/gdrive/MyDrive/imaging/classification/input/400nm/1187.bmp
#   inflating: /content/gdrive/MyDrive/imaging/classification/input/400nm/1188.bmp
#   inflating: /content/gdrive/MyDrive/imaging/classification/input/400nm/1189.bmp
#   inflating: /content/gdrive/MyDrive/imaging/classification/input/400nm/119.bmp
#   inflating: /content/gdrive/MyDrive/imaging/classification/input/400nm/1190.bmp
#   inflating: /content/gdrive/MyDrive/imaging/classification/input/400nm/1191.bmp
#   inflating: /content/gdrive/MyDrive/imaging/classification/input/400nm/1192.bmp
#   inflating: /content/gdrive/MyDrive/imaging/classification/input/400nm/1193.bmp
#   inflating: /content/gdrive/MyDrive/imaging/classification/input/400nm/1194.bmp
#   inflating: /content/gdrive/MyDrive/imaging/classification/input/400nm/1195.bmp
#   inflating: /content/gdrive/MyDrive/imaging/classification/input/400nm/1196.bmp
#   inflating: /content/gdrive/MyDrive/imaging/classification/input/400nm/1197.bmp
#   inflating: /content/gdrive/MyDrive/imaging/classification/input/400nm/1198.bmp
#   inflating: /content/gdrive/MyDrive/imaging/classification/input/400nm/1199.bmp
#   inflating: /content/gdrive/MyDrive/imaging/classification/input/400nm/12.bmp
#   inflating: /content/gdrive/MyDrive/imaging/classification/input/400nm/120.bmp
#   inflating: /content/gdrive/MyDrive/imaging/classification/input/400nm/1200.bmp
#   inflating: /content/gdrive/MyDrive/imaging/classification/input/400nm/1201.bmp
#   inflating: /content/gdrive/MyDrive/imaging/classification/input/400nm/1202.bmp
#   inflating: /content/gdrive/MyDrive/imaging/classification/input/400nm/1203.bmp
#   inflating: /content/gdrive/MyDrive/imaging/classification/input/400nm/1204.bmp
#   inflating: /content/gdrive/MyDrive/imaging/classification/input/400nm/1205.bmp
#   inflating: /content/gdrive/MyDrive/imaging/classification/input/400nm/1206.bmp
#   inflating: /content/gdrive/MyDrive/imaging/classification/input/400nm/1207.bmp
#   inflating: /content/gdrive/MyDrive/imaging/classification/input/400nm/1208.bmp
#   inflating: /content/gdrive/MyDrive/imaging/classification/input/400nm/1209.bmp
#   inflating: /content/gdrive/MyDrive/imaging/classification/input/400nm/121.bmp
#   inflating: /content/gdrive/MyDrive/imaging/classification/input/400nm/1210.bmp
#   inflating: /content/gdrive/MyDrive/imaging/classification/input/400nm/1211.bmp
#   inflating: /content/gdrive/MyDrive/imaging/classification/input/400nm/1212.bmp
#   inflating: /content/gdrive/MyDrive/imaging/classification/input/400nm/1213.bmp
#   inflating: /content/gdrive/MyDrive/imaging/classification/input/400nm/1214.bmp

# %%
# %cd /content/gdrive/MyDrive/imaging/classification

# !unzip ./input.zip -d /content/gdrive/MyDrive/imaging/classification/input/

# %cd /content/gdrive/MyDrive/imaging/classification/

# !python classificationnew.py
# Out:
# [Errno 2] No such file or directory: '/content/gdrive/MyDrive/imaging/classification'
# /content
# unzip:  cannot find or open ./input.zip, ./input.zip.zip or ./input.zip.ZIP.
# [Errno 2] No such file or directory: '/content/gdrive/MyDrive/imaging/classification/'
# /content
# python3: can't open file '/content/classificationnew.py': [Errno 2] No such file or directory

# %%
import os
import numpy as np

# 检查文件夹是否存在，如果不存在则创建
save_dir = '/content/gdrive/MyDrive/imaging/classification/results'
os.makedirs(save_dir, exist_ok=True)

# 然后继续执行保存操作
numpy_confusion_matrix_path = os.path.join(save_dir, 'confusion_matrix.npy')
np.save(numpy_confusion_matrix_path, cm)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-3c63dc62282d> in <cell line: 10>()
#       8 # 然后继续执行保存操作
#       9 numpy_confusion_matrix_path = os.path.join(save_dir, 'confusion_matrix.npy')
# ---> 10 np.save(numpy_confusion_matrix_path, cm)
#
# NameError: name 'cm' is not defined

# %%
import os
import torch
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
from torchvision.datasets import ImageFolder
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sns
import numpy as np

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# 数据集路径
data_dir = '/content/gdrive/MyDrive/imaging/classification/input'
save_path = '/content/gdrive/MyDrive/imaging/classification/Net.pth'
result_path = '/content/gdrive/MyDrive/imaging/classification/results/training_plot.png'

# 定义数据变换
transform = transforms.Compose([
    transforms.Resize((128, 128)),  # 修改尺寸
    transforms.Grayscale(),
    transforms.ToTensor(),
    transforms.Normalize(mean=0.5, std=0.5)
])

# 加载数据集
dataset = ImageFolder(root=data_dir, transform=transform)

# 划分数据集为训练集、测试集和验证集
total_len = len(dataset)
train_len = int(0.7 * total_len)
val_len = int(0.1 * total_len)
test_len = total_len - train_len - val_len

train_dataset, val_dataset, test_dataset = torch.utils.data.random_split(
    dataset, [train_len, val_len, test_len]
)

# 创建数据加载器
train_loader = DataLoader(train_dataset, batch_size=256, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=256, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=256, shuffle=False)

# 定义卷积模型
class Net(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(1, 32, kernel_size=3, padding=1)
        self.act1 = nn.Tanh()
        self.pool1 = nn.MaxPool2d(2)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, padding=1)
        self.act2 = nn.Tanh()
        self.pool2 = nn.MaxPool2d(2)
        self.conv3 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
        self.act3 = nn.Tanh()
        self.pool3 = nn.MaxPool2d(2)
        self.conv4 = nn.Conv2d(128, 256, kernel_size=3, padding=1)
        self.act4 = nn.Tanh()
        self.pool4 = nn.MaxPool2d(2)
        self.fc1 = nn.Linear(256*8*8, 64)
        self.act5 = nn.Tanh()
        self.fc2 = nn.Linear(64, 5)

    def forward(self, x):
        out = self.pool1(self.act1(self.conv1(x)))
        out = self.pool2(self.act2(self.conv2(out)))
        out = self.pool3(self.act3(self.conv3(out)))
        out = self.pool4(self.act4(self.conv4(out)))
        out = out.view(-1, 256*8*8)
        out = self.act5(self.fc1(out))
        out = self.fc2(out)
        return out

# 初始化模型、损失函数和优化器
model = Net().to(device)
criterion = nn.CrossEntropyLoss().to(device)
optimizer = optim.Adam(model.parameters(), lr=0.001)

# 初始化列表用于存储训练和验证的损失和准确率
train_losses, val_losses = [], []
train_accuracies, val_accuracies = [], []

# 训练模型
num_epochs = 10
for epoch in range(num_epochs):
    model.train()
    train_loss = 0
    correct_train = 0
    total_train = 0
    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        _, predicted = torch.max(outputs, 1)
        total_train += labels.size(0)
        correct_train += (predicted == labels).sum().item()

    train_losses.append(train_loss / len(train_loader))
    train_accuracy = correct_train / total_train
    train_accuracies.append(train_accuracy)

    # 在验证集上评估模型
    model.eval()
    val_loss = 0
    correct_val = 0
    total_val = 0
    with torch.no_grad():
        for inputs, labels in val_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            val_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            total_val += labels.size(0)
            correct_val += (predicted == labels).sum().item()

    val_losses.append(val_loss / len(val_loader))
    val_accuracy = correct_val / total_val
    val_accuracies.append(val_accuracy)

    print(f'Epoch {epoch}, Training Loss: {train_loss / len(train_loader)}, Training Accuracy: {train_accuracy}, Validation Loss: {val_loss / len(val_loader)}, Validation Accuracy: {val_accuracy}')

# 在测试集上评估模型
model.eval()
test_loss = 0
correct_test = 0
total_test = 0
with torch.no_grad():
    for inputs, labels in test_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        test_loss += loss.item()
        _, predicted = torch.max(outputs, 1)
        total_test += labels.size(0)
        correct_test += (predicted == labels).sum().item()

test_accuracy = correct_test / total_test
print(f'Test Loss: {test_loss / len(test_loader)}, Test Accuracy: {test_accuracy}')

# 保存模型
torch.save(model.state_dict(), save_path)

# 绘制训练和验证的损失及准确率图像
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Validation Loss')
plt.title('Loss over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(train_accuracies, label='Train Accuracy')
plt.plot(val_accuracies, label='Validation Accuracy')
plt.title('Accuracy over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.savefig(result_path)
print(f"Plot saved to {result_path}")

# 在测试集上评估模型并计算混淆矩阵
true_labels = []
pred_labels = []
model.eval()
with torch.no_grad():
    for inputs, labels in test_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)
        _, predicted = torch.max(outputs, 1)
        true_labels.extend(labels.cpu().numpy())
        pred_labels.extend(predicted.cpu().numpy())

# 计算混淆矩阵
cm = confusion_matrix(true_labels, pred_labels)
class_names = dataset.classes  # 获取类别名称

# 绘制混淆矩阵
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.title('confusion matrix')
plt.ylabel('real')
plt.xlabel('predict')
plt.tight_layout()  # 确保没有内容被裁剪
confusion_matrix_path = '/content/gdrive/MyDrive/imaging/classification/results/confusion_matrix.png'
plt.savefig(confusion_matrix_path)
plt.show()
print(f"already save {confusion_matrix_path}")
# 保存为Numpy数组格式
numpy_confusion_matrix_path = '/content/gdrive/MyDrive/imaging/classification/results/confusion_matrix.npy'
np.save(numpy_confusion_matrix_path, cm)
print(f"混淆矩阵已保存为NumPy数组格式至 {numpy_confusion_matrix_path}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-ad989d70e31f> in <cell line: 29>()
#      27
#      28 # 加载数据集
# ---> 29 dataset = ImageFolder(root=data_dir, transform=transform)
#      30
#      31 # 划分数据集为训练集、测试集和验证集
#
# /usr/local/lib/python3.10/dist-packages/torchvision/datasets/folder.py in __init__(self, root, transform, target_transform, loader, is_valid_file, allow_empty)
#     326         allow_empty: bool = False,
#     327     ):
# --> 328         super().__init__(
#     329             root,
#     330             loader,
#
# /usr/local/lib/python3.10/dist-packages/torchvision/datasets/folder.py in __init__(self, root, loader, extensions, transform, target_transform, is_valid_file, allow_empty)
#     147     ) -> None:
#     148         super().__init__(root, transform=transform, target_transform=target_transform)
# --> 149         classes, class_to_idx = self.find_classes(self.root)
#     150         samples = self.make_dataset(
#     151             self.root,
#
# /usr/local/lib/python3.10/dist-packages/torchvision/datasets/folder.py in find_classes(self, directory)
#     232             (Tuple[List[str], Dict[str, int]]): List of all classes and dictionary mapping each class to an index.
#     233         """
# --> 234         return find_classes(directory)
#     235
#     236     def __getitem__(self, index: int) -> Tuple[Any, Any]:
#
# /usr/local/lib/python3.10/dist-packages/torchvision/datasets/folder.py in find_classes(directory)
#      39     See :class:`DatasetFolder` for details.
#      40     """
# ---> 41     classes = sorted(entry.name for entry in os.scandir(directory) if entry.is_dir())
#      42     if not classes:
#      43         raise FileNotFoundError(f"Couldn't find any class folder in {directory}.")
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/gdrive/MyDrive/imaging/classification/input'
